# %%
import SampleGeneration
import EstimationMethods
import WindowEstimation
import MethodComparisons
import importlib
importlib.reload(SampleGeneration)
importlib.reload(EstimationMethods)
importlib.reload(WindowEstimation)
importlib.reload(MethodComparisons)
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(0)
n=1000
oversampling=100
lambda_=0.3
theta_=2
kappa_=1
sample_size=10000
label_offset=0

# %%
dist_results = MethodComparisons.estimator_distributions(sample_size=sample_size, n=n, oversampling=oversampling, lambda_=lambda_, theta_=theta_, kappa_=kappa_, initial=[1,1,1], relevant_lags = 3)
# Out:
# Start time: 2023-09-20 15:27:54; Progress: 0%
# End time: 2023-09-20 16:20:45; Progress: 0%

# %%
MethodComparisons.plot_estimator_distributions(dist_results, sample_size=sample_size, lambda_=lambda_, theta_=theta_, kappa_=kappa_, label_offset=label_offset)

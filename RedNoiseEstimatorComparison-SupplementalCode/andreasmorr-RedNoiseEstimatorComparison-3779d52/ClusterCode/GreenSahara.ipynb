# %%
import GS_data_analysis
import importlib
importlib.reload(GS_data_analysis)
# Out:
# <module 'GS_data_analysis' from '/Users/andreasmorr/Library/Mobile Documents/com~apple~CloudDocs/PhD Studium/Eigene Papers/EstimationLandscape/RedNoiseEstimatorComparison/ClusterCode/GS_data_analysis.py'>

# %%
GS_data_analysis.plot_cell("lat26_lon1")

# %%
GS_data_analysis.plot_all_cells()

# %% [markdown]
# For one of the analysed cells, the runtimes of the estimation routines are calculated to give an impression of the relative computational costs of the methods.

# %%
GS_data_analysis.plot_cell_time("lat26_lon1")
# Out:
# Time elapsed for each estimation routine:
# Variance V total: 0.21992278099060059s
# Variance V per window: 8.458568499638484e-05s
# AC(1) V total: 0.4214029312133789s
# AC(1) V per window: 0.00016207805046668418s
# PSD V total: 2.0602900981903076s
# PSD V per window: 0.22892112202114528s
# PSD P total: 1.3695299625396729s
# PSD P per window: 0.15216999583774143s
# ACS V total: 0.028272151947021484s
# ACS V per window: 0.0031413502163357204s
# ACS P: 0.03671908378601074s
# ACS P per window: 0.004079898198445638s
# Total time elapsed for the estimation routines: 4.137075901031494s

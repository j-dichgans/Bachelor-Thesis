# %%
import SampleGeneration
import EstimationMethods
import WindowEstimation
import MethodComparisons
import importlib
importlib.reload(SampleGeneration)
importlib.reload(EstimationMethods)
importlib.reload(WindowEstimation)
importlib.reload(MethodComparisons)
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(0)
n=14000
observation_length=1
windowsize=700
leap=700
lambda_scale = 0.4
theta_start = 3
theta_end = 0.9
kappa_start = 1.2
kappa_end = 3.4

# %%
MethodComparisons.plot_example_est(n=n, observation_length=observation_length, windowsize=windowsize, leap=leap, lambda_scale=lambda_scale, theta_start=theta_start, theta_end=theta_end, kappa_start=kappa_start, kappa_end=kappa_end,labels_right=False)

# %%
np.random.seed(5)#5#21
n=14000
observation_length=0.6
windowsize=700
leap=700
lambda_scale = 0.4
theta_start = 1
theta_end = 3.7
kappa_start = 3.3
kappa_end = 2.2

# %%
MethodComparisons.plot_example_est(n=n, observation_length=observation_length, windowsize=windowsize, leap=leap, lambda_scale=lambda_scale, theta_start=theta_start, theta_end=theta_end, kappa_start=kappa_start, kappa_end=kappa_end,labels_right=True)
